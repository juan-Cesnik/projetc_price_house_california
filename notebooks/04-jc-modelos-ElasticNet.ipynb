# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
    "regressor__reg__alpha":[1E-2, 5E-2, 0.1, 0.25, 0.5, 1.0],
    "regressor__reg__l1_ratio":[0.1, 0.25, 0.5, 0.75, 0.9],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=ElasticNet(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# C:\Users\juaramin\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.426e+02, tolerance: 1.801e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 0.01,
#  'regressor__reg__l1_ratio': 0.1}

# %%
#Esse resultado você ja percebe que compensa usar o ridge doque o lasso

# %%
grid_search.best_score_
# Out:
# np.float64(-51290.160730563686)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_INLAND                       -0.605823
# robust_scaler_poly__longitude                         -0.383899
# robust_scaler_poly__population_per_household          -0.344638
# robust_scaler_poly__latitude                          -0.214150
# robust_scaler_poly__latitude^2                        -0.195535
# ...                                                         ...
# ordinal_encoder__median_income_cat                     0.093128
# robust_scaler_poly__housing_median_age longitude^2     0.108608
# robust_scaler_poly__bedrooms_per_room                  0.132033
# robust_scaler_poly__housing_median_age median_i...     0.182324
# robust_scaler_poly__median_income                      0.725236
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
#                                                     coeficiente
# robust_scaler_poly__housing_median_age median_i...         -0.0
# robust_scaler_poly__housing_median_age total_ro...         -0.0
# robust_scaler_poly__latitude^3                              0.0
# robust_scaler_poly__housing_median_age populati...         -0.0
# robust_scaler_poly__housing_median_age total_be...         -0.0
# ...                                                         ...
# robust_scaler_poly__bedrooms_per_room rooms_per...          0.0
# robust_scaler_poly__bedrooms_per_room populatio...          0.0
# robust_scaler_poly__bedrooms_per_room populatio...          0.0
# robust_scaler_poly__bedrooms_per_room total_roo...         -0.0
# robust_scaler_poly__bedrooms_per_room populatio...         -0.0
#
# [209 rows x 1 columns]

# %%
coefs[coefs["coeficiente"].between(-0.1, 0.1)& (coefs["coeficiente"]!=0)]
# Out:
#                                                     coeficiente
# robust_scaler_poly__bedrooms_per_room^2 median_...    -0.083708
# robust_scaler_poly__bedrooms_per_room^2 latitude      -0.075731
# robust_scaler_poly__housing_median_age latitude       -0.067369
# robust_scaler_poly__median_income^2                   -0.066332
# robust_scaler_poly__median_income population_pe...    -0.061608
# ...                                                         ...
# robust_scaler_poly__total_bedrooms                     0.076365
# robust_scaler_poly__housing_median_age populati...     0.085741
# robust_scaler_poly__housing_median_age                 0.088580
# robust_scaler_poly__median_income total_bedrooms       0.092738
# ordinal_encoder__median_income_cat                     0.093128
#
# [143 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.1, 0.1)])

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "LinearRegression_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
# C:\Users\juaramin\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.404e+01, tolerance: 1.427e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\juaramin\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.305e+01, tolerance: 1.429e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\juaramin\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.688e+01, tolerance: 1.423e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\juaramin\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.511e+02, tolerance: 1.417e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\juaramin\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.787e+01, tolerance: 1.427e+00
#   model = cd_fast.enet_coordinate_descent(
#                            model  fit_time score_time   test_r2  \
# 0                 DummyRegressor  0.004948   0.004668 -0.000081
# 1                 DummyRegressor  0.003747   0.004652 -0.000146
# 2                 DummyRegressor  0.004652   0.007937 -0.001737
# 3                 DummyRegressor  0.003571   0.007999 -0.000101
# 4                 DummyRegressor  0.003109   0.009306 -0.000114
# 5               LinearRegression  0.032674   0.010511  0.682162
# 6               LinearRegression  0.027292   0.009469   0.66999
# 7               LinearRegression  0.025259   0.009625  0.649247
# 8               LinearRegression  0.025068   0.009993  0.669873
# 9               LinearRegression  0.023699   0.009747  0.669023
# 10       LinearRegression_target  0.034395   0.010775   0.69174
# 11       LinearRegression_target  0.032356   0.009807   0.67797
# 12       LinearRegression_target  0.031224   0.027991  0.654296
# 13       LinearRegression_target  0.031652   0.010511  0.683829
# 14       LinearRegression_target   0.03261   0.010409  0.682322
# 15  LinearRegression_grid_search  8.140676   0.025231  0.734627
# 16  LinearRegression_grid_search  5.683723   0.027221   0.71365
# 17  LinearRegression_grid_search  5.243068   0.021763  0.688309
# 18  LinearRegression_grid_search  6.878226   0.020411  0.717921
# 19  LinearRegression_grid_search  4.489791   0.020548  0.716017
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.009616
# 1                 -75787.787194                    -95217.629397     0.008398
# 2                 -76753.598961                    -96253.253947     0.012589
# 3                 -76837.804811                    -95983.885799      0.01157
# 4                 -76617.245449                    -96182.764729     0.012415
# 5                 -39855.690996                    -54254.958188     0.043185
# 6                 -40272.565467                    -54695.230283     0.036761
# 7                  -42178.05929                    -56955.988706     0.034885
# 8                 -40806.492497                    -55146.318803     0.035061
# 9                 -40788.496497                     -55331.35106     0.033446
# 10                -37810.981373                    -53431.240327      0.04517
# 11                -38289.952572                    -54029.904534     0.042163
# 12                -40283.193967                    -56544.507086     0.059214
# 13                -38597.175854                    -53968.143766     0.042163
# 14                -38423.813819                    -54208.355112      0.04302
# 15                -34873.321419                    -49575.290962     8.165907
# 16                -35642.551649                    -50948.876346     5.710944
# 17                 -37608.30541                     -53690.86563      5.26483
# 18                -35932.449373                    -50975.542209     6.898637
# 19                -35965.469796                    -51252.877611     4.510339

# %%
df_resultados.groupby("model").mean()
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                0.004005   0.006912 -0.000436
# LinearRegression              0.026798   0.009869  0.668059
# LinearRegression_grid_search  6.087097   0.023035  0.714105
# LinearRegression_target       0.032447   0.013899  0.678031
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_grid_search                -36004.419529
# LinearRegression_target                     -38681.023517
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.010918
# LinearRegression                                -55276.769408     0.036667
# LinearRegression_grid_search                    -51288.690552     6.110132
# LinearRegression_target                         -54436.430165     0.046346

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                0.004005   0.006912 -0.000436
# LinearRegression              0.026798   0.009869  0.668059
# LinearRegression_target       0.032447   0.013899  0.678031
# LinearRegression_grid_search  6.087097   0.023035  0.714105
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_target                     -38681.023517
# LinearRegression_grid_search                -36004.419529
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.010918
# LinearRegression                                -55276.769408     0.036667
# LinearRegression_target                         -54436.430165     0.046346
# LinearRegression_grid_search                    -51288.690552     6.110132

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)

# %%
#A gente usou o elastic net, para obervar se tem alguma melhoria comparado com o que agente tinha antes, a metrica melhorou? A metrica esta na mesma faixa de valor você observa isso la no best score, o que melhorou foi a compreensão do modelo porque como a gente diminuiu a importancia de alguns coeficientes e destacando os que eram mais relavantes em relação ao seu target, porem o tempo esta muito alto
